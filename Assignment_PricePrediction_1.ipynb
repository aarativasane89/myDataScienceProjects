# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("AB_NYC_2019.csv")

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
data.shape
# Out:
# (48895, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48879 non-null object
# host_id                           48895 non-null int64
# host_name                         48874 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# ...

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
plt.figure(figsize=(17,10))
sns.heatmap(data.isnull(),cbar=True,)

# %%
data.duplicated().value_counts()
# Out:
# False    48895
# dtype: int64

# %%
plt.figure(figsize=(17,9))
sns.heatmap(data.corr(),annot=True)

# %%
data["id"].describe()
# Out:
# count    4.889500e+04
# mean     1.901714e+07
# std      1.098311e+07
# min      2.539000e+03
# 25%      9.471945e+06
# 50%      1.967728e+07
# 75%      2.915218e+07
# max      3.648724e+07
# Name: id, dtype: float64

# %%
data["id"].nunique() # It means no repeated or duplicate values
# Out:
# 48895

# %%
data["name"].describe()
# Out:
# count              48879
# unique             47905
# top       Hillside Hotel
# freq                  18
# Name: name, dtype: object

# %%
data["name"].nunique() # Quiet big number so there must not be any relation inbetween price and name feature
# Out:
# 47905

# %%
data["host_id"].nunique() # Quiet big number so there must not be any relation inbetween price and host_id feature
# Out:
# 37457

# %%
data["host_id"].describe()
# Out:
# count    4.889500e+04
# mean     6.762001e+07
# std      7.861097e+07
# min      2.438000e+03
# 25%      7.822033e+06
# 50%      3.079382e+07
# 75%      1.074344e+08
# max      2.743213e+08
# Name: host_id, dtype: float64

# %%
data["host_name"].nunique()
# Out:
# 11452

# %%
data["host_name"].describe()
# Out:
# count       48874
# unique      11452
# top       Michael
# freq          417
# Name: host_name, dtype: object

# %%
data.drop(['id','name','host_id','host_name'], axis=1, inplace=True) # As per the observation or analyzation the mention features are not that useul

# %%
data.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# availability_365                  48895 non-null int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 4.5+ MB

# %%
data.isnull().sum()
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data.columns # the remaining columns areas follows
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ## lets go one by one column

# %% [markdown]
# #### 1. neighbourhood_group

# %%
data['neighbourhood_group'].describe()
# Out:
# count         48895
# unique            5
# top       Manhattan
# freq          21661
# Name: neighbourhood_group, dtype: object

# %%
data['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
data['neighbourhood_group'].nunique()
# Out:
# 5

# %%
data['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
plt.figure(figsize=(17,9))
sns.barplot(data=data, x='neighbourhood_group',y='price')
meanPrice_neighbourhoodGroup = data.groupby("neighbourhood_group")["price"].mean()
print(meanPrice_neighbourhoodGroup)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
plt.figure(figsize=(17,9))
sns.barplot(data=data, x='neighbourhood_group',y='price', hue='room_type')

# %% [raw]
# # The price for the EntireRoom/apt is very high in manhatten as compare to the price for EntireRoom/Apt in other neightbourhood_groups
# # The price for the EntireRoom/apt is less in Bronx as compare to the price for EntireRoom/Apt in other neightbourhood_groups
# # The price for the shared room is high in manhatten as compare to price of shared room in other neighbourhood_groups
# # The price for the shared room is very less in Brooklyn as compare to price of shared room in other neighbourhood_groups
# # The price for the private room is high in manhatten as compare to price of shared room in other neighbourhood_groups
# # The price for the private room is less in Staten Island as compare to price of shared room in other neighbourhood_groups
#
# ### Manhatten neighbourhood_group is costier than other neighbourhood_group

# %% [markdown]
# #### 2.neighbourhood

# %%
data['neighbourhood'].value_counts()
# Out:
# Williamsburg                  3920
# Bedford-Stuyvesant            3714
# Harlem                        2658
# Bushwick                      2465
# Upper West Side               1971
# Hell's Kitchen                1958
# East Village                  1853
# Upper East Side               1798
# Crown Heights                 1564
# Midtown                       1545
# East Harlem                   1117
# Greenpoint                    1115
# Chelsea                       1113
# Lower East Side                911
# Astoria                        900
# Washington Heights             899
# West Village                   768
# Financial District             744
# Flatbush                       621
# Clinton Hill                   572
# Long Island City               537
# Prospect-Lefferts Gardens      535
# Park Slope                     506
# East Flatbush                  500
# Fort Greene                    489
# Murray Hill                    485
# Kips Bay                       470
# ...

# %%
data['neighbourhood'].describe()
# Out:
# count            48895
# unique             221
# top       Williamsburg
# freq              3920
# Name: neighbourhood, dtype: object

# %%
data['neighbourhood'].nunique()
# Out:
# 221

# %%
data['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
plt.figure(figsize=(16,9))
sns.barplot(data=data, x=data['neighbourhood'], y=data['price'])
## From below plot we are not getting any clear information and  we are having neighbourhood_group feature which is more informative so in future we will drop neighbourhood column

# %% [markdown]
# #### 3. latitude

# %%
data['latitude'].describe()
# Out:
# count    48895.000000
# mean        40.728949
# std          0.054530
# min         40.499790
# 25%         40.690100
# 50%         40.723070
# 75%         40.763115
# max         40.913060
# Name: latitude, dtype: float64

# %%
data['latitude'].nunique()
# Out:
# 19048

# %%
data['latitude'].unique()
# Out:
# array([40.64749, 40.75362, 40.80902, ..., 40.80953, 40.70184, 40.81475])

# %%
plt.figure(figsize=(17,9))
sns.distplot(data['latitude'])
# In below distplot we can see that distribution is normal or latitude

# %%
plt.figure(figsize=(17,9))
sns.scatterplot(x=data['longitude'], y=data['latitude'], hue=data['room_type'])

# %%
plt.figure(figsize=(17,9))
sns.scatterplot(x=data['longitude'], y=data['latitude'], hue=data['neighbourhood_group'])

# %% [markdown]
# #### 4. longitude

# %%
data['longitude'].describe()
# Out:
# count    48895.000000
# mean       -73.952170
# std          0.046157
# min        -74.244420
# 25%        -73.983070
# 50%        -73.955680
# 75%        -73.936275
# max        -73.712990
# Name: longitude, dtype: float64

# %%
data['longitude'].nunique()
# Out:
# 14718

# %%
data['longitude'].unique()
# Out:
# array([-73.97237, -73.98377, -73.9419 , ..., -73.87727, -73.93614,
#        -73.80844])

# %%
plt.figure(figsize=(17,9))
sns.distplot(data['longitude'])

# %%
plt.figure(figsize=(17,9))
sns.scatterplot(x=data['price'], y=data['longitude'], hue=data['room_type'])

# %%
plt.figure(figsize=(17,9))
sns.scatterplot(x=data['price'], y=data['longitude'], hue=data['neighbourhood_group'])

# %% [markdown]
# #### 5. room_type

# %%
data['room_type'].describe()
# Out:
# count               48895
# unique                  3
# top       Entire home/apt
# freq                25409
# Name: room_type, dtype: object

# %%
data['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
data['room_type'].nunique()
# Out:
# 3

# %%
data['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
plt.figure(figsize = (17,9))
sns.barplot(data=data, x=data.room_type, y=data.price)
meanPrice_roomType = data.groupby("room_type")["price"].mean()
print(meanPrice_roomType)
# Out:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price, dtype: float64

# %%
plt.figure(figsize = (17,13))
sns.boxplot(data=data, x=data.room_type, y=data.price)

# %% [markdown]
# #### 5. Price

# %%
data["price"].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
data["price"].nunique()
# Out:
# 674

# %%
data["price"].unique()
# Out:
# array([  149,   225,   150,    89,    80,   200,    60,    79,   135,
#           85,   120,   140,   215,    99,   190,   299,   130,   110,
#           44,   180,    50,    52,    55,    70,    35,    40,    68,
#          115,   151,   228,   144,    69,    49,   375,   250,   275,
#          230,    51,    65,   105,    95,   145,   285,    94,   800,
#          131,    98,   100,   125,   175,   500,   101,   220,    59,
#          350,   199,   325,   235,   170,   400,    75,    90,   185,
#           77,    76,   160,   195,   156,   219,   475,   165,   196,
#           83,   123,   265,   249,   121,    45,    71,    64,   159,
#          189,   239,   305,   155,    92,    36,    37,   205,    39,
#          390,   129,   212,   124,   122,   109,   575,   229,   169,
#          113,   179,   349,   139,   650,    67,   599,   211,   290,
#           87,   395,   260,    97,   132,   141,   495,   259,    96,
# ...

# %%
plt.figure(figsize = (17,9))
sns.distplot(data.price, hist= True, kde = True)

# %%
# In above plot we can see that the prices are lies between 0 to 1000

# %%
plt.figure(figsize=(17,9))
sns.distplot(data['price'][data.price<=1000], hist= True, kde = True)

# %%
data['price'][data.price<=1000].count()
# Out:
# 48656

# %%
# lets check for outliers using boxplot
plt.figure(figsize = (13,9))
sns.boxplot(y=data['price'])

# %%
# Findout outliers using z-score
outliers=[]
def detect_outlier_price():
    threshold=3
    mean_1 = data['price'].mean()
    std_1 =data['price'].std()
    for y in data['price']:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    print(len(outliers))

# %%
detect_outlier_price()
# Out:
# 388

# %% [markdown]
# #### 6. minimum_nights

# %%
data['minimum_nights'].describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
data['minimum_nights'].nunique()
# Out:
# 109

# %%
data['minimum_nights'].unique()
# Out:
# array([   1,    3,   10,   45,    2,    5,    4,   90,    7,   14,   60,
#          29,   30,  180,    9,   31,    6,   15,    8,   26,   28,  200,
#          50,   17,   21,   11,   25,   13,   35,   27,   18,   20,   40,
#          44,   65,   55,  120,  365,  122,   19,  240,   88,  115,  150,
#         370,   16,   80,  181,  265,  300,   59,  185,  360,   56,   12,
#          70,   39,   24,   32, 1000,  110,  270,   22,   75,  250,   62,
#          23, 1250,  364,   74,  198,  100,  500,   43,   91,  480,   53,
#          99,  160,   47,  999,  186,  366,   68,   93,   87,  183,  299,
#         175,   98,  133,  354,   42,   33,   37,  225,  400,  105,  184,
#         153,  134,  222,   58,  210,  275,  182,  114,   85,   36],
#       dtype=int64)

# %%
data['minimum_nights'].value_counts()
# Out:
# 1       12720
# 2       11696
# 3        7999
# 30       3760
# 4        3303
# 5        3034
# 7        2058
# 6         752
# 14        562
# 10        483
# 29        340
# 15        279
# 20        223
# 28        203
# 31        201
# 21        135
# 8         130
# 60        106
# 90        104
# 12         91
# 25         82
# 9          80
# 13         54
# 180        43
# 11         33
# 45         32
# 365        29
# 18         28
# 120        28
# 16         18
#         ...
# 198         1
# 480         1
# 36          1
# 134         1
# 58          1
# 250         1
# 400         1
# 185         1
# 153         1
# 184         1
# 183         1
# 87          1
# 182         1
# 85          1
# 275         1
# 370         1
# 114         1
# 175         1
# 39          1
# 222         1
# 366         1
# 122         1
# 299         1
# 43          1
# 74          1
# 42          1
# 186         1
# 265         1
# 1000        1
# 364         1
# ...

# %%
# lets plot the dist plot to see distribution
plt.figure(figsize = (15,7))
sns.distplot(data.minimum_nights, hist= True, kde = True)

# %%
# lets go in detail
plt.figure(figsize = (17,9))
sns.distplot(data['minimum_nights'][data.minimum_nights<=100], hist= True, kde = True)

# %%
data['minimum_nights'][data.minimum_nights<=100].count()
# Out:
# 48721

# %%
# lets go in detail
plt.figure(figsize = (17,9))
sns.distplot(data['minimum_nights'][data.minimum_nights<=35], hist= True, kde = True)

# %%
data['minimum_nights'][data.minimum_nights<=35].count() # As we can see here 99% data lies between 0 to 35 so rest of the data points we can consider as outliers
# Out:
# 48374

# %%
# lets check for outliers using boxplot
plt.figure(figsize=(13,9))
sns.boxplot(y=data['minimum_nights'])

# %%
plt.figure(figsize=(17,9))
sns.scatterplot(x=data['price'], y=data['minimum_nights'], hue=data['room_type'])

# %%
plt.figure(figsize=(17,9))
sns.scatterplot(x=data['price'], y=data['minimum_nights'], hue=data['neighbourhood_group'])

# %%
# lets check for outliers using z-score
outliers=[]
def detect_outlier_minimum_nights():
    threshold=3
    mean_1 = data['minimum_nights'].mean()
    std_1 =data['minimum_nights'].std()
    for y in data['minimum_nights']:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    print(len(outliers))

# %%
detect_outlier_minimum_nights()
# Out:
# 327

# %% [markdown]
# #### 7. number_of_reviews

# %%
data['number_of_reviews'].describe()
# Out:
# count    48895.000000
# mean        23.274466
# std         44.550582
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64

# %%
data['number_of_reviews'].unique()
# Out:
# array([  9,  45,   0, 270,  74,  49, 430, 118, 160,  53, 188, 167, 113,
#         27, 148, 198, 260, 130,  39,  71,  88,  19,  58, 108,  29, 242,
#        197, 273, 168, 231, 214, 245,  15,  25,  81,  97,  11, 248,  61,
#        135, 112,  73,  82, 328, 105, 289, 138,  21,  42,   5,  66, 143,
#        191,   4, 338, 106, 190,  23, 142,  54,  70,  16,  94, 194,   2,
#        174,  24, 166,   1,  30, 139, 233,  68,  46, 335, 162, 170, 334,
#         12, 467,   7,  38, 324, 115, 354, 195,  13,  36,  63, 155, 193,
#         32,  50,  26, 426, 227,  84,   3,  10, 124, 240, 200,  79,  34,
#        134, 126, 234, 202,  28, 309,  14,  80, 294, 150,  47, 219, 114,
#        213,  86,  18, 206, 122,  33,  52,  51, 199,  41, 109, 151, 285,
#        375,   6, 358, 226, 104, 204, 253, 129,  37,  69, 192,  17, 222,
#        205, 458, 183, 189, 127,  35, 171,  92, 238,  56, 111, 147, 177,
#        185,  62, 181, 333, 441, 279, 203, 210,  64, 132,  20,  67, 187,
# ...

# %%
data['number_of_reviews'].nunique()
# Out:
# 394

# %%
data['number_of_reviews'].value_counts()
# Out:
# 0      10052
# 1       5244
# 2       3465
# 3       2520
# 4       1994
# 5       1618
# 6       1357
# 7       1179
# 8       1127
# 9        964
# 10       803
# 11       778
# 12       682
# 13       611
# 14       575
# 15       536
# 16       471
# 17       461
# 18       417
# 19       401
# 20       391
# 22       344
# 23       337
# 21       333
# 25       313
# 24       305
# 26       299
# 28       258
# 27       253
# 29       244
#        ...
# 264        1
# 217        1
# 408        1
# 310        1
# 374        1
# 326        1
# 335        1
# 454        1
# 282        1
# 597        1
# 378        1
# 474        1
# 459        1
# 363        1
# 299        1
# 467        1
# 308        1
# 340        1
# 451        1
# 411        1
# 458        1
# 394        1
# 330        1
# 298        1
# 372        1
# 404        1
# 436        1
# 388        1
# 341        1
# 607        1
# Name: number_of_reviews, Length: 394, dtype: int64

# %%
# lets check the distribution
plt.figure(figsize = (17,9))
sns.distplot(data['number_of_reviews'], hist= True, kde=True)

# %%
plt.figure(figsize = (17,9))
sns.distplot(data['number_of_reviews'][data['number_of_reviews']<150], hist= True, kde=True)

# %%
data['number_of_reviews'][data['number_of_reviews']<150].count()
# Out:
# 47525

# %%
# lets findout for outliers
plt.figure(figsize = (13,9))
sns.boxplot(y = data['number_of_reviews'])

# %%
# lets check for outliers using z-score
outliers=[]
def detect_outlier_number_of_reviews():
    threshold=3
    mean_1 = data['number_of_reviews'].mean()
    std_1 =data['number_of_reviews'].std()
    for y in data['number_of_reviews']:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    print(len(outliers))

# %%
detect_outlier_number_of_reviews()
# Out:
# 1221

# %%
# get some more information
plt.figure(figsize = (13,9))
sns.scatterplot(x= data['price'],y = data['number_of_reviews'],hue=data.room_type)

# %%
# from above scatter plot we can say that EntireRoom/ apt are reviewed more as compare to the other two types
# there are very less or almost no review for shared rooms
# The price for mostly reviewed rooms are between $0 to $2000

# %%
# get some more information
plt.figure(figsize = (13,9))
sns.scatterplot(x= data['price'],y = data['number_of_reviews'],hue=data.neighbourhood_group)

# %%
# from above scatter plot we can say that cheaper rooms are reviewed more number of times
# The cheapest rooms are available in Queens and that are reviewed more number of times
# Manhatten neighbourhood_group is having highest number of reviews
# the costier rooms are having very less number of reviews

# %%
# get some more information
plt.figure(figsize = (13,9))
sns.scatterplot(x= data['price'],y = data['number_of_reviews'],hue=data.neighbourhood_group)

# %%
# The number of reviews are more for Queens the reason might be the price is less
# After Queens the 2nd rank for more number of review is manhtten
# There are very less or almost no reviews for Staten Island and Bronx

# %% [markdown]
# #### 7. last_review

# %%
data['last_review'].describe() # this is basically
# Out:
# count          38843
# unique          1764
# top       2019-06-23
# freq            1413
# Name: last_review, dtype: object

# %%
type(data['last_review'][0])
# Out:
# str

# %%
data['last_review'].duplicated().value_counts()
# Out:
# True     47130
# False     1765
# Name: last_review, dtype: int64

# %%
data['last_review'].nunique() # did not find this column useful as its not giving any important information
# Out:
# 1764

# %% [markdown]
# #### 8. reviews_per_month

# %%
data['reviews_per_month'].describe()
# Out:
# count    38843.000000
# mean         1.373221
# std          1.680442
# min          0.010000
# 25%          0.190000
# 50%          0.720000
# 75%          2.020000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %%
data["reviews_per_month"].isnull().sum()
# Out:
# 10052

# %%
type(data["reviews_per_month"][0])
# Out:
# numpy.float64

# %%
# so as we can see 10052 values are missing in "reviews_per_month" column.
# missing values means no one reviewed that particular property in the month.
# So null means 0 , so we will fill missing values with 0

data["reviews_per_month"].fillna(0, inplace=True)

# %%
data["reviews_per_month"].isnull().sum()
# Out:
# 0

# %%
# lets see distribution 
plt.figure(figsize = (17,9))
sns.distplot(data.reviews_per_month, hist=True, kde=True)

# %%
# lets see distribution 
plt.figure(figsize = (17,9))
sns.distplot(data["reviews_per_month"][data.reviews_per_month<6], hist=True, kde=True)

# %%
data["reviews_per_month"][data.reviews_per_month<6].count()
# Out:
# 48104

# %%
# lets findout for outliers
plt.figure(figsize = (13,9))
sns.boxplot(y = data['reviews_per_month'])

# %%
# lets check for outliers using z-score
outliers=[]
def detect_outlier_reviews_per_month():
    threshold=3
    mean_1 = data['reviews_per_month'].mean()
    std_1 =data['reviews_per_month'].std()
    for y in data['reviews_per_month']:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    print(len(outliers))

# %%
detect_outlier_reviews_per_month()
# Out:
# 847

# %%
# lets see some relations
plt.figure(figsize = (13,9))
sns.scatterplot(x= data['price'],y = data['reviews_per_month'],hue=data.room_type)

# %%
# from above scatter plot we can say that EntireRoom/ apt are reviewed more as compare to the other two types
# there are very less or almost no review for shared rooms
# The price for mostly reviewed rooms are between $0 to $2000

# %%
# lets see some relations
plt.figure(figsize = (13,9))
sns.scatterplot(x= data['price'],y = data['reviews_per_month'],hue=data.neighbourhood_group)

# %%
# Manhatten,Queens and Brooklyn are having more number of reviews per month.

# %%
data.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# #### 9. calculated_host_listings_count

# %%
data['calculated_host_listings_count'].describe()
# Out:
# count    48895.000000
# mean         7.143982
# std         32.952519
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        327.000000
# Name: calculated_host_listings_count, dtype: float64

# %%
data['calculated_host_listings_count'].value_counts()
# Out:
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 50        50
# 25        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: calculated_host_listings_count, dtype: int64

# %%
data['calculated_host_listings_count'].nunique()
# Out:
# 47

# %%
plt.figure(figsize=(10,9))
sns.distplot(data.calculated_host_listings_count, hist =True, kde = True)

# %%
plt.figure(figsize=(10,9))
sns.distplot(data["calculated_host_listings_count"][data.calculated_host_listings_count<10], hist =True, kde = True)

# %%
data["calculated_host_listings_count"][data.calculated_host_listings_count<10].count()
# Out:
# 45718

# %%
# lets findout outlier using boxplot
plt.figure(figsize=(10,9))
sns.boxplot(y=data["calculated_host_listings_count"])

# %%
# lets findout outlier using z-score
def detect_outlier_calculated_host_listings_count():
    threshold=3
    mean_1 = data['calculated_host_listings_count'].mean()
    std_1 =data['calculated_host_listings_count'].std()
    for y in data['calculated_host_listings_count']:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    print(len(outliers))

# %%
detect_outlier_calculated_host_listings_count()
# Out:
# 1527

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(x=data['price'],y=data["calculated_host_listings_count"],hue=data["room_type"])

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(x=data['price'],y=data["calculated_host_listings_count"],hue=data["neighbourhood_group"])

# %% [markdown]
# #### 10. availability_365

# %%
data['availability_365'].describe()
# Out:
# count    48895.000000
# mean       112.781327
# std        131.622289
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        227.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
data['availability_365'].nunique()
# Out:
# 366

# %%
plt.figure(figsize=(15,9))
sns.distplot(data["availability_365"], hist=True, kde=True)

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data=data,y=data.availability_365)# No outlier

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(x=data['price'],y=data["availability_365"],hue=data["room_type"])

# %%
# the availability of rooms ranked as follow:
# 1. Entire home/apt
# 2. Private room
# 3. Shared room

# %%
plt.figure(figsize=(10,9))
sns.scatterplot(x=data['price'],y=data["availability_365"],hue=data["neighbourhood_group"])

# %%
# The availabilty of rooms in manhatten, brooklyn and Queens are for 365 days
# The rooms in Staten Island and Bronx are very less and the availbility is also not for all 365 days

# %% [markdown]
# ### Feature Selection

# %%
# As we have concluded columns last_review and neighbourhood are not that useful for building lets drop them
data.drop(['last_review','neighbourhood'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['neighbourhood_group', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
plt.figure(figsize=(17,9))
sns.heatmap(data.corr(), annot=True)

# %%
data.shape
# Out:
# (48895, 10)

# %% [markdown]
# ### label Encoding

# %%
data_Dummies = pd.get_dummies(data, columns=['room_type','neighbourhood_group'],drop_first=True)

# %%
data_Dummies.shape
# Out:
# (48895, 14)

# %%
data_Dummies.columns
# Out:
# Index(['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'room_type_Private room', 'room_type_Shared room',
#        'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan',
#        'neighbourhood_group_Queens', 'neighbourhood_group_Staten Island'],
#       dtype='object')

# %%
data_Dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
# latitude                             48895 non-null float64
# longitude                            48895 non-null float64
# price                                48895 non-null int64
# minimum_nights                       48895 non-null int64
# number_of_reviews                    48895 non-null int64
# reviews_per_month                    48895 non-null float64
# calculated_host_listings_count       48895 non-null int64
# availability_365                     48895 non-null int64
# room_type_Private room               48895 non-null uint8
# room_type_Shared room                48895 non-null uint8
# neighbourhood_group_Brooklyn         48895 non-null uint8
# neighbourhood_group_Manhattan        48895 non-null uint8
# neighbourhood_group_Queens           48895 non-null uint8
# neighbourhood_group_Staten Island    48895 non-null uint8
# ...

# %%
plt.figure(figsize=(17,10))
sns.heatmap(data_Dummies.corr(), annot=True)
